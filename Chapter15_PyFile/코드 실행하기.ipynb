# %%
# !python train.py --model_fn tmp.pth --gpu_id -1 --batch_size 256 --n_epochs 20 --n_layers 5
# Out:
# Train: torch.Size([48000, 784]) torch.Size([48000])
# Valid: torch.Size([12000, 784]) torch.Size([12000])
# ImageClassifier(
#   (layers): Sequential(
#     (0): Block(
#       (block): Sequential(
#         (0): Linear(in_features=784, out_features=630, bias=True)
#         (1): LeakyReLU(negative_slope=0.01)
#         (2): BatchNorm1d(630, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Block(
#       (block): Sequential(
#         (0): Linear(in_features=630, out_features=476, bias=True)
#         (1): LeakyReLU(negative_slope=0.01)
#         (2): BatchNorm1d(476, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): Block(
#       (block): Sequential(
#         (0): Linear(in_features=476, out_features=322, bias=True)
#         (1): LeakyReLU(negative_slope=0.01)
#         (2): BatchNorm1d(322, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): Block(
#       (block): Sequential(
#         (0): Linear(in_features=322, out_features=168, bias=True)
#         (1): LeakyReLU(negative_slope=0.01)
#         (2): BatchNorm1d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): Linear(in_features=168, out_features=10, bias=True)
#     (5): LogSoftmax(dim=-1)
#   )
# )
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: False
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
# NLLLoss()
# Epoch(1/20): train_loss=1.9276e-01  valid_loss=1.1244e-01  lowest_loss=1.1244e-01
# Epoch(2/20): train_loss=7.9594e-02  valid_loss=1.1290e-01  lowest_loss=1.1244e-01
# Epoch(3/20): train_loss=5.4054e-02  valid_loss=9.5998e-02  lowest_loss=9.5998e-02
# Epoch(4/20): train_loss=4.0230e-02  valid_loss=8.6703e-02  lowest_loss=8.6703e-02
# Epoch(5/20): train_loss=3.1304e-02  valid_loss=8.6975e-02  lowest_loss=8.6703e-02
# Epoch(6/20): train_loss=2.8469e-02  valid_loss=7.2654e-02  lowest_loss=7.2654e-02
# Epoch(7/20): train_loss=2.1773e-02  valid_loss=9.5354e-02  lowest_loss=7.2654e-02
# Epoch(8/20): train_loss=2.2327e-02  valid_loss=7.4391e-02  lowest_loss=7.2654e-02
# Epoch(9/20): train_loss=2.0161e-02  valid_loss=8.0662e-02  lowest_loss=7.2654e-02
# Epoch(10/20): train_loss=1.5499e-02  valid_loss=9.3784e-02  lowest_loss=7.2654e-02
# Epoch(11/20): train_loss=1.5104e-02  valid_loss=1.0178e-01  lowest_loss=7.2654e-02
# Epoch(12/20): train_loss=1.6056e-02  valid_loss=8.5656e-02  lowest_loss=7.2654e-02
# Epoch(13/20): train_loss=1.2583e-02  valid_loss=8.9932e-02  lowest_loss=7.2654e-02
# Epoch(14/20): train_loss=1.3339e-02  valid_loss=9.4218e-02  lowest_loss=7.2654e-02
# Epoch(15/20): train_loss=1.2145e-02  valid_loss=8.9294e-02  lowest_loss=7.2654e-02
# Epoch(16/20): train_loss=9.6091e-03  valid_loss=8.4848e-02  lowest_loss=7.2654e-02
# Epoch(17/20): train_loss=9.7731e-03  valid_loss=8.5347e-02  lowest_loss=7.2654e-02
# Epoch(18/20): train_loss=7.1254e-03  valid_loss=8.6228e-02  lowest_loss=7.2654e-02
# Epoch(19/20): train_loss=1.2372e-02  valid_loss=8.9039e-02  lowest_loss=7.2654e-02

# %% [markdown]
# ## 15.8 predict.ipynb 구현하기

# %%
# 라이브러리 불러오기

import torch
import torch.nn

import sys
import numpy as np
import matplotlib.pyplot as plt

from model import ImageClassifier

from utils import load_mnist
from utils import split_data
from utils import get_hidden_sizes

# 모델 불러오기

model_fn = "./tmp.pth"

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

def load(fn, device):
    d = torch.load(fn, map_location=device)
    return d['model'], d['config']

# 결과 확인

def plot(x, y_hat):
    for i in range(x.size(0)):
        img = (np.array(x[i].detach().cpu(), dtype='float')).reshape(28,28)

        plt.imshow(img, cmap='gray')
        plt.show()
        print("Predict:", float(torch.argmax(y_hat[i], dim=-1)))

# %%
# test 결과 구하기

def test(model, x, y, to_be_shown = True):
    model.eval()

    with torch.no_grad():
        y_hat = model(x)

        correct_cnt = (y.squeeze() == torch.argmax(y_hat, dim=-1)).sum()
        total_cnt = float(x.size(0))
        
        accuracy = correct_cnt / total_cnt
        print("Accuracy: %.4f" % accuracy)
        
        if to_be_shown:
            plot(x, y_hat)

# %%
# 추론(test) 수행

model_dict, train_config = load(model_fn, device)

x, y = load_mnist(is_train = False)

x, y = x.to(device), y.to(device)

input_size = int(x.shape[-1])
output_size = int(max(y)) + 1

model = ImageClassifier(
    input_size=input_size,
    output_size=output_size,
    hidden_sizes=get_hidden_sizes(input_size,
                                  output_size,
                                  train_config.n_layers),
    use_batch_norm=not train_config.use_dropout,
    dropout_p=train_config.dropout_p,
).to(device)

model.load_state_dict(model_dict)

test(model, x, y, to_be_shown=False)
# Out:
# Accuracy: 0.9792

# %%
n_test = 20
test(model, x[:n_test], y[:n_test], to_be_shown=True)
# Out:
# Accuracy: 0.9500
# Predict: 7.0
# Predict: 2.0
# Predict: 1.0
# Predict: 0.0
# Predict: 4.0
# Predict: 1.0
# Predict: 4.0
# Predict: 9.0
# Predict: 5.0
# Predict: 9.0
# Predict: 0.0
# Predict: 6.0
# Predict: 9.0
# Predict: 0.0
# Predict: 1.0
# Predict: 5.0
# Predict: 9.0
# Predict: 7.0
# Predict: 5.0
# Predict: 4.0
